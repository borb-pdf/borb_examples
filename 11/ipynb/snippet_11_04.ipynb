# %% [markdown]
# <a href="https://colab.research.google.com/github/jorisschellekens/borb-examples-dev/blob/master/snippet_11_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install borb
# Out:
# Collecting borb
#   Downloading borb-3.0.5-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: setuptools>=51.1.1 in /usr/local/lib/python3.12/dist-packages (from borb) (75.2.0)
# Downloading borb-3.0.5-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 32.3 MB/s eta 0:00:00
# Installing collected packages: borb
# Successfully installed borb-3.0.5

# %%
# snippet_11_04.ipynb
from borb.pdf import ByFontColor
from borb.pdf import Document
from borb.pdf import GetText
from borb.pdf import PDF
from borb.pdf import Pipeline
from borb.pdf import Source
from borb.pdf import X11Color

import pathlib
import requests


def download_pdf(url: str, filename: pathlib.Path) -> None:
    """
    Downloads a PDF file from the given URL and saves it to the specified filename.

    :param url: The URL of the PDF file to download.
    :param filename: The local file path where the downloaded PDF should be saved.

    :raises requests.exceptions.RequestException: If there is an issue with the HTTP request (e.g., network failure, invalid URL, bad response).
    :raises Exception: If any other unexpected error occurs during file writing.
    """
    try:
        response = requests.get(url, stream=True)
        response.raise_for_status()  # Raise an exception for bad status codes
        with open(filename, "wb") as pdf_file:
            for chunk in response.iter_content(chunk_size=8192):
                pdf_file.write(chunk)
    except requests.exceptions.RequestException as e:
        print(f"Error downloading PDF: {e}")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")


# Download
download_pdf(
    "https://github.com/borb-pdf/borb-pdf-corpus/raw/refs/heads/master/pdf/0002.pdf",
    pathlib.Path("input.pdf"),
)

# Read PDF
d: Document = PDF.read("input.pdf")

# Process the PDF to get the text
output = Pipeline(
    [
        Source(),
        ByFontColor(font_color=X11Color.WHITE),
        GetText(),
    ]
).process(d)

# Print the text
print(output)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipython-input-1061955033.py in <cell line: 0>()
#      50         GetText(),
#      51     ]
# ---> 52 ).process(d)
#      53
#      54 # Print the text
#
# /usr/local/lib/python3.12/dist-packages/borb/pdf/toolkit/pipeline.py in process(self, document_or_page)
#      96             for i in range(0, document_or_page.get_number_of_pages()):
#      97                 page: Page = document_or_page.get_page(i)
# ---> 98                 source.process_page(page=page)
#      99                 source.process(EndPageEvent(page=page))
#     100
#
# /usr/local/lib/python3.12/dist-packages/borb/pdf/toolkit/source/operator/source.py in process_page(self, page)
#     470                     args += [operands.pop(-1)]  # type: ignore[list-item]
#     471                 args.reverse()
# --> 472                 operator.apply(
#     473                     operands=args,  # type: ignore[arg-type]
#     474                     page=page,
#
# /usr/local/lib/python3.12/dist-packages/borb/pdf/toolkit/source/operator/operator_Tj.py in apply(self, operands, page, source)
#     186                 # fmt: on
#     187             text_being_rendered = "".join(
# --> 188                 [source.font.get_character(c) for c in unescaped_operand]
#     189             )
#     190
#
# /usr/local/lib/python3.12/dist-packages/borb/pdf/font/font.py in get_character(self, character_code)
#     196         :raises KeyError: If the character code cannot be resolved using the available encoding information.
#     197         """
# --> 198         self.__build_character_encoding_dictionaries()
#     199         return self.__character_code_to_character.get(character_code, "�")
#     200
#
# /usr/local/lib/python3.12/dist-packages/borb/pdf/font/font.py in __build_character_encoding_dictionaries(self)
#      70             from borb.pdf.font.cmap import CMap
#      71
# ---> 72             assert isinstance(cmap, CMap)
#      73             for k in range(cmap.first_character_code(), cmap.last_character_code() + 1):
#      74                 try:
#
# AssertionError:
